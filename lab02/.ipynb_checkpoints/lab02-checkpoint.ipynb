# %%
import collections
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

data = pd.read_csv('results.csv')

# %%
data_text = pd.DataFrame(data = data, columns = ['text'])

# %%
text = []

# %%
for i in range(0, data_text.size):
    string = data_text.loc[[i], ['text']].get_values().item(0)
    splitted = re.split("[ ,.]", string)
    for palavra in splitted:
        if len(palavra) > 2:
            text.append(palavra)

text
# Out:
# ['juíza',
#  'federal',
#  'Ivani',
#  'Silva',
#  'Luz',
#  'Brasília',
#  'proibiu',
#  'caráter',
#  'liminar',
#  'nesta',
#  'sexta-feira',
#  'Forças',
#  'Armadas',
#  'comemorarem',
#  'especialmente',
#  'com',
#  'uso',
#  'dinheiro',
#  'público',
#  '55º',
#  'aniversário',
#  'golpe',
#  'Estado',
#  'que',
#  '1964',
#  'instaurou',
#  'ditadura',
#  'militar',
#  'Brasil',
#  '—os',
#  'militares',
#  'preferem',
#  'março',
#  'abril—',
#  'partiu',
#  'presidente',
#  'ultradireita',
#  'Jair',
#  'Bolsonaro',
#  'que',
#  'depois',
#  'tentou',
#  'suavizar',
#  'ordem',
#  'citando',
#  'que',
#  'era',
#  'dia',
#  'para',
#  '"rememorar"',
#  'Para',
#  'Silva',
#  'Luz',
#  'texto',
#  'divulgado',
#  'pelo',
#  'Ministério',
#  'Defesa',
#  'como',
#  '"ordem',
#  'dia',
#  'alusiva',
#  'Março',
#  '1964"',
#  'lida',
#  'alguns',
#  'quartéis',
#  '"não',
#  'compatível',
#  'com',
#  'processo',
#  'reconstrução',
#  'democrática"',
#  'promovido',
#  'pela',
#  'Constituição',
#  '1988',
#  '\xa0"desobedece',
#  'princípio',
#  'prevalência',
#  'dos',
#  'direitos',
#  'humanos"',
#  'ignora',
#  'decisão',
#  'Corte',
#  'Interamericana',
#  'Direitos',
#  'Humanos',
#  '2018',
#  'que',
#  'condenou',
#  'Estado',
#  'Brasileiro',
#  'apurar',
#  'julgar',
#  'responsáveis',
#  'pela',
#  'morte',
#  'jornalista',
#  'Vladimir',
#  'Herzog',
#  'ditadura',
#  'militar',
#  'magistrada',
#  'que',
#  'também',
#  'pontua',
#  'que',
#  'datas',
#  'comemorativas',
#  'devem',
#  'ser',
#  'aprovadas',
#  'pelo',
#  'Congresso',
#  'justapõe',
#  'texto',
#  'chancelado',
#  'pelas',
#  'Forças',
#  'Armadas',
#  'com',
#  'discurso',
#  'presidente',
#  'Assembleia',
#  'Constituinte',
#  'Ulysses',
#  'Guimarães',
#  'promulgação',
#  'Carta',
#  '1988',
#  'Para',
#  'juíza',
#  'texto',
#  'dos',
#  'militares',
#  'uma',
#  '"celebração',
#  'ruptura',
#  'política',
#  'deflagrada',
#  'pelas',
#  'Forças',
#  'Armadas"',
#  'dizer',
#  'que',
#  'golpistas',
#  '"agiram',
#  'conforme',
#  'anseios',
#  'Nação',
#  'Brasileira"',
#  'dura',
#  'sentença',
#  'Silva',
#  'Luz',
#  'diz',
#  'que',
#  'mensagem',
#  '"desobedece',
#  'princípio',
#  'prevalência',
#  'dos',
#  'direitos',
#  'humanos"',
#  'contraria',
#  'compromisso',
#  'com',
#  'valores',
#  'democráticos',
#  '"canalizado',
#  'pelo',
#  'discurso',
#  'presidente',
#  'Assembleia',
#  'Nacional',
#  'Constituinte"',
#  'sentença',
#  'cita',
#  'trechos',
#  'fala',
#  'Ulysses',
#  'Guimarães',
#  'sociedade',
#  'foi',
#  'Rubens',
#  'Paiva',
#  'não',
#  'facínoras',
#  'que',
#  'mataram”',
#  'disse',
#  '1988',
#  'emedebista',
#  'referência',
#  'porta-voz',
#  'Presidência',
#  'não',
#  'comentou',
#  'decisão',
#  'que',
#  'nós',
#  'tínhamos',
#  'falar',
#  'longo',
#  'semana',
#  'falamos',
#  'Não',
#  'temos',
#  'mais',
#  'nada',
#  'para',
#  'comentar"',
#  'disse',
#  'nesta',
#  'sexta',
#  'Segundo',
#  'Ministério',
#  'Defesa',
#  'informou',
#  'não',
#  'ter',
#  'recebido',
#  'decisão',
#  'que',
#  'proíbe',
#  'ordem',
#  'dia',
#  'que',
#  'ainda',
#  'estava',
#  'até',
#  'publicação',
#  'desta',
#  'reportagem',
#  'disponível',
#  'nos',
#  'sites',
#  'Marinha',
#  'Exército',
#  'Aeronáutica',
#  'proibição',
#  'legal',
#  'traz',
#  'ainda',
#  'mais',
#  'tensão',
#  'para',
#  'fim',
#  'semana',
#  'avançada',
#  'sexta-feira',
#  'ministro',
#  'STF',
#  '(Supremo',
#  'Tribunal',
#  'Federal)',
#  'Gilmar',
#  'Mendes',
#  'negou',
#  'dar',
#  'seguimento',
#  'mandado',
#  'segurança',
#  'apresentado',
#  'por',
#  'parentes',
#  'vítimas',
#  'ditadura',
#  'pelo',
#  'Instituto',
#  'Vladimir',
#  'Herzog',
#  'para',
#  'suspender',
#  'atos',
#  'comemoração',
#  'golpe',
#  'militar',
#  '1964',
#  'Mendes',
#  'não',
#  'entrou',
#  'mérito',
#  'questão',
#  'afirmando',
#  'que',
#  'instrumento',
#  'legal',
#  'não',
#  'aplicava',
#  'Ainda',
#  'assim',
#  'usou',
#  'sua',
#  'sentença',
#  'para',
#  'comentar',
#  'questão',
#  'repetir',
#  'elogiosamente',
#  'definição',
#  'presidente',
#  'corte',
#  'Antonio',
#  'Dias',
#  'Toffoli',
#  'que',
#  'disse',
#  'passado:',
#  '“Hoje',
#  'não',
#  'refiro',
#  'nem',
#  'mais',
#  'golpe',
#  'nem',
#  'revolução',
#  'refiro',
#  'movimento',
#  '1964',
#  'frase',
#  'interpretação',
#  'vesgamente',
#  'enviesada',
#  'procura',
#  'que',
#  'não',
#  'existe',
#  'história',
#  'tem',
#  'como',
#  'resultado',
#  'golpe',
#  'dos',
#  'golpistas',
#  'limite',
#  'este',
#  'limite',
#  'foi',
#  'agora',
#  'ultrapassado',
#  'pelo',
#  'Toffoli',
#  'preconizam',
#  'deixar',
#  'falar',
#  'ditadura"',
#  'disse',
#  'PAÍS',
#  'historiador',
#  'Menos',
#  'horas',
#  'depois',
#  'juíza',
#  'federal',
#  'Ivani',
#  'Silva',
#  'Luz',
#  'que',
#  'completa',
#  'anos',
#  'neste',
#  'domingo',
#  'Justiça',
#  'Federal',
#  'derrubou',
#  'decisão',
#  'Por',
#  'meio',
#  'uma',
#  'liminar',
#  'Justiça',
#  'proibiu',
#  'noite',
#  'desta',
#  'sexta-feira',
#  'comemorações',
#  'golpe',
#  'especialmente',
#  'com',
#  'uso',
#  'dinheiro',
#  'público',
#  'Mas',
#  'Advocacia',
#  'Geral',
#  'União',
#  '(AGU)',
#  'recorreu',
#  'poucas',
#  'horas',
#  'depois',
#  'manhã',
#  'deste',
#  'sábado',
#  'desembargadora',
#  'Maria',
#  'Carmo',
#  'Cardoso',
#  'cassou',
#  'liminar',
#  'partiu',
#  'presidente',
#  'ultradireita',
#  'Jair',
#  'Bolsonaro',
#  'que',
#  'após',
#  'polêmica',
#  'torno',
#  'caso',
#  'tentou',
#  'suavizar',
#  'ordem',
#  'afirmando',
#  'que',
#  'era',
#  'dia',
#  'para',
#  '"rememorar"',
#  'Defensoria',
#  'Pública',
#  'União',
#  'entrou',
#  'então',
#  'com',
#  'pedido',
#  'suspensão',
#  'das',
#  'celebrações',
#  'afirmando',
#  'que',
#  'qualquer',
#  'evento',
#  'relacionado',
#  'golpe',
#  'militar',
#  'feria',
#  'memória',
#  'verdades',
#  'históricas',
#  'Mas',
#  'visão',
#  'AGU',
#  'ações',
#  'propostas',
#  'pela',
#  'Defensoria',
#  'não',
#  'preenchiam',
#  'requisitos',
#  'necessários',
#  'para',
#  'concessão',
#  'uma',
#  'liminar',
#  'fosse',
#  'mantida',
#  'decisão',
#  'poderia',
#  'visão',
#  'AGU',
#  '"afetar',
#  'separação',
#  'visões',
#  'constitucionais',
#  'Estado"',
#  'Advocacia',
#  'alega',
#  'que',
#  'Defensoria',
#  'deveria',
#  'atuar',
#  '"primordialmente',
#  'defesa',
#  'pessoas',
#  'carentes',
#  'recursos',
#  'econômicos',
#  'necessitados',
#  'jurídicos"',
#  'que',
#  'não',
#  'cabe',
#  'nesse',
#  'caso',
#  'Quando',
#  'determinou',
#  'que',
#  'março',
#  '1964',
#  'uma',
#  'estratégia',
#  'polêmica',
#  'mudar',
#  'narrativa',
#  'sobre',
#  'como',
#  'conta',
#  'história',
#  'trouxe',
#  'tona',
#  'discussões',
#  'antes',
#  'isoladas',
#  'universo',
#  'acadêmico',
#  'Afinal',
#  'tática',
#  'seria',
#  'uma',
#  'simples',
#  'revisão',
#  'para',
#  'enriquecer',
#  'que',
#  'sabe',
#  'até',
#  'agora',
#  'sobre',
#  'ditadura',
#  'uma',
#  'negação',
#  'dos',
#  'fatos',
#  'históricos?',
#  'ministro',
#  'Educação',
#  'deu',
#  'contribuição',
#  'ainda',
#  'mais',
#  'controversa',
#  'para',
#  'questão',
#  'afirmou',
#  'que',
#  'que',
#  'ocorreu',
#  'março',
#  'não',
#  'foi',
#  'golpe',
#  'mas',
#  '"um',
#  'regime',
#  'democrático',
#  'força"',
#  'que',
#  'país',
#  'deve',
#  'mudar',
#  'livros',
#  'didáticos',
#  'para',
#  '"resgatar',
#  'uma',
#  'versão',
#  'história',
#  'mais',
#  'ampla"',
#  'sobre',
#  'período',
#  '1964',
#  '1985',
#  'Nesta',
#  'quinta',
#  'que',
#  'Governo',
#  'federal',
#  'teria',
#  'enviado',
#  'telegrama',
#  'Fabian',
#  'Salvioli',
#  'relator',
#  'especial',
#  'Organização',
#  'das',
#  'Nações',
#  'Unidas',
#  '(ONU)',
#  'sobre',
#  'Promoção',
#  'Verdade',
#  'Justiça',
#  'Reparação',
#  'afirmando',
#  'que',
#  '“não',
#  'ouve',
#  'golpe',
#  'Estado”',
#  'que',
#  'anos',
#  'governo',
#  'militar',
#  'foram',
#  'necessários',
#  'para',
#  'afastar',
#  'ameaça',
#  'comunista',
#  'Essa',
#  'escalada',
#  'discurso',
#  'político',
#  'para',
#  'mudar',
#  'narrativa',
#  'sobre',
#  'golpe',
#  'militar',
#  'entanto',
#  'não',
#  'reverbera',
#  'historiografia',
#  'Segundo',
#  'Marcos',
#  'Napolitano',
#  'professor',
#  'Universidade',
#  'São',
#  'Paulo',
#  '(USP)',
#  'autor',
#  'livros',
#  'sobre',
#  'história',
#  'ditadura',
#  'militar',
#  'falar',
#  '“regime',
#  'democrático',
#  'força”',
#  'uma',
#  'contradição',
#  '“Esta',
#  'mais',
#  'para',
#  'negacionismo',
#  'histórico',
#  'que',
#  'revisionismo”',
#  'afirma',
#  'Napolitano',
#  'explica',
#  'que',
#  'conceito',
#  'negacionismo',
#  'tipo',
#  'afirmação',
#  'histórica',
#  'que',
#  'não',
#  'tem',
#  'base',
#  'documental',
#  'que',
#  'distorce',
#  'processo',
#  'factual',
#  'que',
#  'simplesmente',
#  'trabalha',
#  'com',
#  'documentos',
#  'falsos',
#  'com',
#  'objetivo',
#  'negar',
#  'processos',
#  'que',
#  'são',
#  'consensuais',
#  'diferença',
#  'sutil',
#  'mas',
#  'revisionismo',
#  'está',
#  'dentro',
#  'debate',
#  'historiográfico',
#  'ancora',
#  'métodos',
#  'aceitos',
#  'cria',
#  'novos',
#  'objetos',
#  'pesquisa',
#  'novos',
#  'problemas',
#  'novas',
#  'questões',
#  'fazendo',
#  'com',
#  'que',
#  'próprio',
#  'historiador',
#  'questione',
#  'suas',
#  'crenças',
#  'que',
#  'saudável”',
#  'conta',
#  '“Já',
#  'negacionismo',
#  'tem',
#  'ponto',
#  'partida',
#  'ideológico',
#  'com',
#  'objetivo',
#  'ocultar',
#  'passado',
#  '”Pesquisadores',
#  'que',
#  'estudam',
#  'têm',
#  'debruçado',
#  'sobre',
#  'questão',
#  'apoiada',
#  'inclusive',
#  'por',
#  'alguns',
#  'historiadores',
#  'Mas',
#  'geral',
#  'comunidade',
#  'historiográfica',
#  'não',
#  'aceita',
#  'porque',
#  'ponto',
#  'partida',
#  'ocultar',
#  'que',
#  'aconteceu”',
#  'explica',
#  'Napolitano',
#  'professor',
#  'afirma',
#  'que',
#  'discussões',
#  'historiográficas',
#  'mais',
#  'recentes',
#  'revisaram',
#  'muitos',
#  'aspectos',
#  'memória',
#  'sobre',
#  'ditadura',
#  'militar',
#  'Brasil',
#  'seu',
#  'artigo',
#  'Napolitano',
#  'afirma',
#  'que',
#  '“existe',
#  'uma',
#  'memória',
#  'hegemônica',
#  'crítica',
#  'regime',
#  'militar”',
#  'construída',
#  'concordância',
#  'entre',
#  'setores',
#  'liberais',
#  '(que',
#  'até',
#  'apoiaram',
#  'golpe',
#  'inicialmente)',
#  'movimentos',
#  'das',
#  'esquerdas',
#  'mas',
#  'cuja',
#  'narrativa',
#  'passou',
#  'por',
#  'correções',
#  'Por',
#  'exemplo',
#  'ênfase',
#  'visão',
#  '“sociedade',
#  'vítima”',
#  'regime',
#  'golpe',
#  'como',
#  'obra',
#  'exclusiva',
#  'dos',
#  'militares',
#  '“Novas',
#  'abordagens',
#  'vem',
#  'problematizando',
#  'questão',
#  'golpe',
#  'como',
#  'ausência',
#  'apoio',
#  'popular',
#  'Pois',
#  'evidência',
#  'apoio',
#  'passeatas',
#  'feitas',
#  'pela',
#  'classe',
#  'média',
#  'Por',
#  'mais',
#  'que',
#  'seja',
#  'incômodo',
#  'para',
#  'memória',
#  'esquerda',
#  'dizer',
#  'que',
#  'teve',
#  'apoio',
#  'Mas',
#  'foi',
#  'apoio',
#  'classe',
#  'média',
#  'não',
#  'grupos',
#  'populares”',
#  'conta',
#  'Outra',
#  'revisão',
#  'sobre',
#  'percepção',
#  'comum',
#  'passado',
#  'que',
#  'guerrilha',
#  'armada',
#  'período',
#  'militar',
#  'foi',
#  'reação',
#  'ato',
#  'institucional',
#  'que',
#  'embruteceu',
#  'regime',
#  '“Não',
#  'foi',
#  'guerrilha',
#  'foi',
#  'projeto',
#  'anterior',
#  'como',
#  'reação',
#  'golpe”',
#  'afirma',
#  'Napolitano',
#  'acordo',
#  'com',
#  'ele',
#  'medida',
#  'que',
#  'novas',
#  'fontes',
#  'documentos',
#  'vão',
#  'aparecendo',
#  'historiadores',
#  'podem',
#  'confrontar',
#  'memória',
#  'seja',
#  'direita',
#  'seja',
#  'esquerda',
#  '“Esse',
#  'trabalho',
#  'historiador',
#  'Nosso',
#  'compromisso',
#  'com',
#  'ampliação',
#  'conhecimento',
#  'não',
#  'com',
#  'negação',
#  'conhecimento',
#  '”Apesar',
#  'afirmar',
#  'que',
#  'revisionismo',
#  'saudável',
#  'Napolitano',
#  'afirma',
#  'que',
#  'limites',
#  'uma',
#  'vez',
#  'que',
#  'não',
#  'pode',
#  'negar',
#  'aspectos',
#  'fundamentais',
#  'fato',
#  'histórico',
#  'como',
#  'fato',
#  'que',
#  'ditadura',
#  'militar',
#  'Brasil',
#  'matou',
#  'centenas',
#  'pessoas',
#  'torturou',
#  'outras',
#  'milhares',
#  'colocando',
#  'xeque',
#  'direitos',
#  'civis',
#  'Brasil',
#  '“História',
#  'memória',
#  'são',
#  'coisas',
#  'paralelas',
#  'por',
#  'isso',
#  'grupo',
#  'não',
#  'pode',
#  'tentar',
#  'impor',
#  'sua',
#  'visão',
#  'dos',
#  'fatos',
#  'debate',
#  'historiográfico',
#  '"Napolitano',
#  'afirma',
#  'que',
#  'processos',
#  'revisionismo',
#  'são',
#  'frequentemente',
#  'turbulentos',
#  'muitas',
#  'vezes',
#  'fruto',
#  'luta',
#  'social',
#  'como',
#  'caso',
#  'história',
#  'indígena',
#  'afrodescentes',
#  'historiografia',
#  'assumiu',
#  'ponto',
#  'vista',
#  'das',
#  'vítimas',
#  'problematizou',
#  'narrativas',
#  'que',
#  'vinham',
#  'passado',
#  'professora',
#  'departamento',
#  'História',
#  'USP',
#  'que',
#  'estuda',
#  'ensino',
#  'história',
#  'afirma',
#  'que',
#  'foram',
#  'movimentos',
#  'sociais',
#  'que',
#  'pressionaram',
#  'para',
#  'mudança',
#  ...]

# %%
c = collections.Counter(text)

# %%
count_more_than_1000 = 0


values = sorted(c.values())

for value in reversed(values):
    if value >= 1000:
        count_more_than_1000 += 1
    else:
        break


count_more_than_1000
# Out:
# 9

# %%
count_once = 0

for value in values:
    if value <= 1:
        count_once += 1
    else:
        break

count_once
# Out:
# 16282

# %%
total_documents = data_text.size
total_word_occurrencies = sum(c.values())
vocabulary_size = len(c.keys())
words_occuring_mt_1000_times = count_more_than_1000
words_occurring_once = count_once

# %%
from scipy import stats as ss

# %%
_50_most_common = c.most_common(50)
_50_most_common
# Out:
# [('que', 6493),
#  ('para', 2212),
#  ('uma', 2100),
#  ('com', 2085),
#  ('não', 1721),
#  ('por', 1229),
#  ('como', 1211),
#  ('mais', 1168),
#  ('dos', 1057),
#  ('sua', 761),
#  ('das', 705),
#  ('foi', 688),
#  ('seu', 654),
#  ('mas', 646),
#  ('anos', 565),
#  ('ser', 496),
#  ('pelo', 462),
#  ('pela', 459),
#  ('também', 445),
#  ('nos', 429),
#  ('sobre', 416),
#  ('muito', 382),
#  ('entre', 379),
#  ('são', 370),
#  ('está', 365),
#  ('presidente', 358),
#  ('Bolsonaro', 358),
#  ('isso', 350),
#  ('ele', 331),
#  ('quando', 326),
#  ('tem', 323),
#  ('era', 321),
#  ('seus', 318),
#  ('Brasil', 307),
#  ('Mas', 299),
#  ('ainda', 287),
#  ('nas', 281),
#  ('depois', 280),
#  ('país', 279),
#  ('até', 278),
#  ('aos', 268),
#  ('Governo', 265),
#  ('sem', 255),
#  ('ter', 252),
#  ('suas', 231),
#  ('pessoas', 229),
#  ('Não', 226),
#  ('contra', 226),
#  ('porque', 219),
#  ('dois', 219)]

# %%
ss.rankdata(_50_most_common)
# Out:
# array([ 88. ,  46. ,  79. ,  10. , 100. ,   7. ,  60. ,   6. ,  78. ,
#          5. ,  84. ,   4. ,  61. ,   3. ,  73. ,   2. ,  66. ,   1. ,
#         94. ,  50. ,  63. ,  49. ,  71. ,  48. ,  91. ,  47. ,  74. ,
#         45. ,  57. ,  44. ,  90. ,  43. ,  82. ,  42. ,  81. ,  41. ,
#         97. ,  40. ,  77. ,  39. ,  93. ,  38. ,  75. ,  37. ,  68. ,
#         36. ,  96. ,  35. ,  70. ,  34. ,  86. ,  32.5,  51. ,  32.5,
#         72. ,  31. ,  67. ,  30. ,  87. ,  29. ,  98. ,  28. ,  69. ,
#         27. ,  92. ,  26. ,  52. ,  25. ,  54. ,  24. ,  56. ,  23. ,
#         76. ,  22. ,  64. ,  21. ,  80. ,  20. ,  59. ,  19. ,  58. ,
#         18. ,  53. ,  17. ,  89. ,  16. ,  99. ,  15. ,  95. ,  14. ,
#         83. ,  13. ,  55. ,  11.5,  62. ,  11.5,  85. ,   8.5,  65. ,
#          8.5])

# %%
ss.rankdata(_50_most_common, method='ordinal')
# Out:
# array([ 88,  46,  79,  10, 100,   7,  60,   6,  78,   5,  84,   4,  61,
#          3,  73,   2,  66,   1,  94,  50,  63,  49,  71,  48,  91,  47,
#         74,  45,  57,  44,  90,  43,  82,  42,  81,  41,  97,  40,  77,
#         39,  93,  38,  75,  37,  68,  36,  96,  35,  70,  34,  86,  32,
#         51,  33,  72,  31,  67,  30,  87,  29,  98,  28,  69,  27,  92,
#         26,  52,  25,  54,  24,  56,  23,  76,  22,  64,  21,  80,  20,
#         59,  19,  58,  18,  53,  17,  89,  16,  99,  15,  95,  14,  83,
#         13,  55,  11,  62,  12,  85,   8,  65,   9], dtype=int64)

# %%
total_word_occurrencies
# Out:
# 155839
