# %%
import collections
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

data = pd.read_csv('results.csv')

# %%
data_text = pd.DataFrame(data = data, columns = ['text'])

# %%
text = []

# %%
for i in range(0, data_text.size):
    string = data_text.loc[[i], ['text']].get_values().item(0)
    splitted = re.split("[ ,.]", string)
    for palavra in splitted:
        if len(palavra) > 2:
            text.append(palavra)

text
# Out:
# ['ju\xc3\xadza',
#  'federal',
#  'Ivani',
#  'Silva',
#  'Luz',
#  'Bras\xc3\xadlia',
#  'proibiu',
#  'car\xc3\xa1ter',
#  'liminar',
#  'nesta',
#  'sexta-feira',
#  'For\xc3\xa7as',
#  'Armadas',
#  'comemorarem',
#  'especialmente',
#  'com',
#  'uso',
#  'dinheiro',
#  'p\xc3\xbablico',
#  '55\xc2\xba',
#  'anivers\xc3\xa1rio',
#  'golpe',
#  'Estado',
#  'que',
#  '1964',
#  'instaurou',
#  'ditadura',
#  'militar',
#  'Brasil',
#  '\xe2\x80\x94os',
#  'militares',
#  'preferem',
#  'mar\xc3\xa7o',
#  '1\xc2\xba',
#  'abril\xe2\x80\x94',
#  'partiu',
#  'presidente',
#  'ultradireita',
#  'Jair',
#  'Bolsonaro',
#  'que',
#  'depois',
#  'tentou',
#  'suavizar',
#  'ordem',
#  'citando',
#  'que',
#  'era',
#  'dia',
#  'para',
#  '"rememorar"',
#  'Para',
#  'Silva',
#  'Luz',
#  'texto',
#  'divulgado',
#  'pelo',
#  'Minist\xc3\xa9rio',
#  'Defesa',
#  'como',
#  '"ordem',
#  'dia',
#  'alusiva',
#  'Mar\xc3\xa7o',
#  '1964"',
#  'j\xc3\xa1',
#  'lida',
#  'alguns',
#  'quart\xc3\xa9is',
#  '"n\xc3\xa3o',
#  'compat\xc3\xadvel',
#  'com',
#  'processo',
#  'reconstru\xc3\xa7\xc3\xa3o',
#  'democr\xc3\xa1tica"',
#  'promovido',
#  'pela',
#  'Constitui\xc3\xa7\xc3\xa3o',
#  '1988',
#  '\xc2\xa0"desobedece',
#  'princ\xc3\xadpio',
#  'preval\xc3\xaancia',
#  'dos',
#  'direitos',
#  'humanos"',
#  'ignora',
#  'decis\xc3\xa3o',
#  'Corte',
#  'Interamericana',
#  'Direitos',
#  'Humanos',
#  '2018',
#  'que',
#  'condenou',
#  'Estado',
#  'Brasileiro',
#  'apurar',
#  'julgar',
#  'respons\xc3\xa1veis',
#  'pela',
#  'morte',
#  'jornalista',
#  'Vladimir',
#  'Herzog',
#  'ditadura',
#  'militar',
#  'magistrada',
#  'que',
#  'tamb\xc3\xa9m',
#  'pontua',
#  'que',
#  'datas',
#  'comemorativas',
#  'devem',
#  'ser',
#  'aprovadas',
#  'pelo',
#  'Congresso',
#  'justap\xc3\xb5e',
#  'texto',
#  'chancelado',
#  'pelas',
#  'For\xc3\xa7as',
#  'Armadas',
#  'com',
#  'discurso',
#  'presidente',
#  'Assembleia',
#  'Constituinte',
#  'Ulysses',
#  'Guimar\xc3\xa3es',
#  'promulga\xc3\xa7\xc3\xa3o',
#  'Carta',
#  '1988',
#  'Para',
#  'ju\xc3\xadza',
#  'texto',
#  'dos',
#  'militares',
#  'uma',
#  '"celebra\xc3\xa7\xc3\xa3o',
#  'ruptura',
#  'pol\xc3\xadtica',
#  'deflagrada',
#  'pelas',
#  'For\xc3\xa7as',
#  'Armadas"',
#  'dizer',
#  'que',
#  'golpistas',
#  '"agiram',
#  'conforme',
#  'anseios',
#  'Na\xc3\xa7\xc3\xa3o',
#  'Brasileira"',
#  'dura',
#  'senten\xc3\xa7a',
#  'Silva',
#  'Luz',
#  'diz',
#  'que',
#  'mensagem',
#  '"desobedece',
#  'princ\xc3\xadpio',
#  'preval\xc3\xaancia',
#  'dos',
#  'direitos',
#  'humanos"',
#  'contraria',
#  'compromisso',
#  'com',
#  'valores',
#  'democr\xc3\xa1ticos',
#  '"canalizado',
#  'pelo',
#  'discurso',
#  'presidente',
#  'Assembleia',
#  'Nacional',
#  'Constituinte"',
#  'senten\xc3\xa7a',
#  'cita',
#  'trechos',
#  'fala',
#  'Ulysses',
#  'Guimar\xc3\xa3es',
#  '\xe2\x80\x9cA',
#  'sociedade',
#  'foi',
#  'Rubens',
#  'Paiva',
#  'n\xc3\xa3o',
#  'fac\xc3\xadnoras',
#  'que',
#  'mataram\xe2\x80\x9d',
#  'disse',
#  '1988',
#  'emedebista',
#  'refer\xc3\xaancia',
#  'porta-voz',
#  'Presid\xc3\xaancia',
#  'n\xc3\xa3o',
#  'comentou',
#  'decis\xc3\xa3o',
#  'que',
#  'n\xc3\xb3s',
#  't\xc3\xadnhamos',
#  'falar',
#  'longo',
#  'semana',
#  'j\xc3\xa1',
#  'falamos',
#  'N\xc3\xa3o',
#  'temos',
#  'mais',
#  'nada',
#  'para',
#  'comentar"',
#  'disse',
#  'nesta',
#  'sexta',
#  'Segundo',
#  'Minist\xc3\xa9rio',
#  'Defesa',
#  'informou',
#  'n\xc3\xa3o',
#  'ter',
#  'recebido',
#  'decis\xc3\xa3o',
#  'que',
#  'pro\xc3\xadbe',
#  'ordem',
#  'dia',
#  'que',
#  'ainda',
#  'estava',
#  'at\xc3\xa9',
#  'publica\xc3\xa7\xc3\xa3o',
#  'desta',
#  'reportagem',
#  'dispon\xc3\xadvel',
#  'nos',
#  'sites',
#  'Marinha',
#  'Ex\xc3\xa9rcito',
#  'Aeron\xc3\xa1utica',
#  'proibi\xc3\xa7\xc3\xa3o',
#  'legal',
#  'traz',
#  'ainda',
#  'mais',
#  'tens\xc3\xa3o',
#  'para',
#  'fim',
#  'semana',
#  'J\xc3\xa1',
#  'avan\xc3\xa7ada',
#  'sexta-feira',
#  'ministro',
#  'STF',
#  '(Supremo',
#  'Tribunal',
#  'Federal)',
#  'Gilmar',
#  'Mendes',
#  'negou',
#  'dar',
#  'seguimento',
#  'mandado',
#  'seguran\xc3\xa7a',
#  'apresentado',
#  'por',
#  'parentes',
#  'v\xc3\xadtimas',
#  'ditadura',
#  'pelo',
#  'Instituto',
#  'Vladimir',
#  'Herzog',
#  'para',
#  'suspender',
#  'atos',
#  'comemora\xc3\xa7\xc3\xa3o',
#  'golpe',
#  'militar',
#  '1964',
#  'Mendes',
#  'n\xc3\xa3o',
#  'entrou',
#  'm\xc3\xa9rito',
#  'quest\xc3\xa3o',
#  'afirmando',
#  'que',
#  'instrumento',
#  'legal',
#  'n\xc3\xa3o',
#  'aplicava',
#  'Ainda',
#  'assim',
#  'usou',
#  'sua',
#  'senten\xc3\xa7a',
#  'para',
#  'comentar',
#  'quest\xc3\xa3o',
#  'repetir',
#  'elogiosamente',
#  'defini\xc3\xa7\xc3\xa3o',
#  'presidente',
#  'corte',
#  'Antonio',
#  'Dias',
#  'Toffoli',
#  'que',
#  'disse',
#  'passado:',
#  '\xe2\x80\x9cHoje',
#  'n\xc3\xa3o',
#  'refiro',
#  'nem',
#  'mais',
#  'golpe',
#  'nem',
#  'revolu\xc3\xa7\xc3\xa3o',
#  'refiro',
#  'movimento',
#  '1964',
#  'frase',
#  'interpreta\xc3\xa7\xc3\xa3o',
#  'vesgamente',
#  'enviesada',
#  'procura',
#  'que',
#  'n\xc3\xa3o',
#  'existe',
#  'hist\xc3\xb3ria',
#  'tem',
#  'como',
#  'resultado',
#  'golpe',
#  'dos',
#  'golpistas',
#  'limite',
#  'este',
#  'limite',
#  'foi',
#  'agora',
#  'ultrapassado',
#  'pelo',
#  'Toffoli',
#  'preconizam',
#  'deixar',
#  'falar',
#  'ditadura"',
#  'disse',
#  'PA\xc3\x8dS',
#  'historiador',
#  'Menos',
#  'horas',
#  'depois',
#  'ju\xc3\xadza',
#  'federal',
#  'Ivani',
#  'Silva',
#  'Luz',
#  'que',
#  'completa',
#  'anos',
#  'neste',
#  'domingo',
#  'Justi\xc3\xa7a',
#  'Federal',
#  'derrubou',
#  'decis\xc3\xa3o',
#  'Por',
#  'meio',
#  'uma',
#  'liminar',
#  'Justi\xc3\xa7a',
#  'proibiu',
#  'noite',
#  'desta',
#  'sexta-feira',
#  'comemora\xc3\xa7\xc3\xb5es',
#  'golpe',
#  'especialmente',
#  'com',
#  'uso',
#  'dinheiro',
#  'p\xc3\xbablico',
#  'Mas',
#  'Advocacia',
#  'Geral',
#  'Uni\xc3\xa3o',
#  '(AGU)',
#  'recorreu',
#  'poucas',
#  'horas',
#  'depois',
#  'manh\xc3\xa3',
#  'deste',
#  's\xc3\xa1bado',
#  'desembargadora',
#  'Maria',
#  'Carmo',
#  'Cardoso',
#  'cassou',
#  'liminar',
#  'partiu',
#  'presidente',
#  'ultradireita',
#  'Jair',
#  'Bolsonaro',
#  'que',
#  'ap\xc3\xb3s',
#  'pol\xc3\xaamica',
#  'torno',
#  'caso',
#  'tentou',
#  'suavizar',
#  'ordem',
#  'afirmando',
#  'que',
#  'era',
#  'dia',
#  'para',
#  '"rememorar"',
#  'Defensoria',
#  'P\xc3\xbablica',
#  'Uni\xc3\xa3o',
#  'entrou',
#  'ent\xc3\xa3o',
#  'com',
#  'pedido',
#  'suspens\xc3\xa3o',
#  'das',
#  'celebra\xc3\xa7\xc3\xb5es',
#  'afirmando',
#  'que',
#  'qualquer',
#  'evento',
#  'relacionado',
#  'golpe',
#  'militar',
#  'feria',
#  'mem\xc3\xb3ria',
#  'verdades',
#  'hist\xc3\xb3ricas',
#  'Mas',
#  'vis\xc3\xa3o',
#  'AGU',
#  'a\xc3\xa7\xc3\xb5es',
#  'propostas',
#  'pela',
#  'Defensoria',
#  'n\xc3\xa3o',
#  'preenchiam',
#  'requisitos',
#  'necess\xc3\xa1rios',
#  'para',
#  'concess\xc3\xa3o',
#  'uma',
#  'liminar',
#  'fosse',
#  'mantida',
#  'decis\xc3\xa3o',
#  'poderia',
#  'vis\xc3\xa3o',
#  'AGU',
#  '"afetar',
#  'separa\xc3\xa7\xc3\xa3o',
#  'vis\xc3\xb5es',
#  'constitucionais',
#  'Estado"',
#  'Advocacia',
#  'alega',
#  'que',
#  'Defensoria',
#  'deveria',
#  'atuar',
#  '"primordialmente',
#  'defesa',
#  'pessoas',
#  'carentes',
#  'recursos',
#  'econ\xc3\xb4micos',
#  'necessitados',
#  'jur\xc3\xaddicos"',
#  'que',
#  'n\xc3\xa3o',
#  'cabe',
#  'nesse',
#  'caso',
#  'Quando',
#  'determinou',
#  'que',
#  'mar\xc3\xa7o',
#  '1964',
#  'uma',
#  'estrat\xc3\xa9gia',
#  'pol\xc3\xaamica',
#  'mudar',
#  'narrativa',
#  'sobre',
#  'como',
#  'conta',
#  'hist\xc3\xb3ria',
#  'trouxe',
#  'tona',
#  'discuss\xc3\xb5es',
#  'antes',
#  'isoladas',
#  'universo',
#  'acad\xc3\xaamico',
#  'Afinal',
#  't\xc3\xa1tica',
#  'seria',
#  'uma',
#  'simples',
#  'revis\xc3\xa3o',
#  'para',
#  'enriquecer',
#  'que',
#  'sabe',
#  'at\xc3\xa9',
#  'agora',
#  'sobre',
#  'ditadura',
#  'uma',
#  'nega\xc3\xa7\xc3\xa3o',
#  'dos',
#  'fatos',
#  'hist\xc3\xb3ricos?',
#  'ministro',
#  'Educa\xc3\xa7\xc3\xa3o',
#  'deu',
#  'contribui\xc3\xa7\xc3\xa3o',
#  'ainda',
#  'mais',
#  'controversa',
#  'para',
#  'quest\xc3\xa3o',
#  'afirmou',
#  'que',
#  'que',
#  'ocorreu',
#  'mar\xc3\xa7o',
#  'n\xc3\xa3o',
#  'foi',
#  'golpe',
#  'mas',
#  '"um',
#  'regime',
#  'democr\xc3\xa1tico',
#  'for\xc3\xa7a"',
#  'que',
#  'pa\xc3\xads',
#  'deve',
#  'mudar',
#  'livros',
#  'did\xc3\xa1ticos',
#  'para',
#  '"resgatar',
#  'uma',
#  'vers\xc3\xa3o',
#  'hist\xc3\xb3ria',
#  'mais',
#  'ampla"',
#  'sobre',
#  'per\xc3\xadodo',
#  '1964',
#  '1985',
#  'Nesta',
#  'quinta',
#  'que',
#  'Governo',
#  'federal',
#  'teria',
#  'enviado',
#  'telegrama',
#  'Fabian',
#  'Salvioli',
#  'relator',
#  'especial',
#  'Organiza\xc3\xa7\xc3\xa3o',
#  'das',
#  'Na\xc3\xa7\xc3\xb5es',
#  'Unidas',
#  '(ONU)',
#  'sobre',
#  'Promo\xc3\xa7\xc3\xa3o',
#  'Verdade',
#  'Justi\xc3\xa7a',
#  'Repara\xc3\xa7\xc3\xa3o',
#  'afirmando',
#  'que',
#  '\xe2\x80\x9cn\xc3\xa3o',
#  'ouve',
#  'golpe',
#  'Estado\xe2\x80\x9d',
#  'que',
#  'anos',
#  'governo',
#  'militar',
#  'foram',
#  'necess\xc3\xa1rios',
#  'para',
#  'afastar',
#  'amea\xc3\xa7a',
#  'comunista',
#  'Essa',
#  'escalada',
#  'discurso',
#  'pol\xc3\xadtico',
#  'para',
#  'mudar',
#  'narrativa',
#  'sobre',
#  'golpe',
#  'militar',
#  'entanto',
#  'n\xc3\xa3o',
#  'reverbera',
#  'historiografia',
#  'Segundo',
#  'Marcos',
#  'Napolitano',
#  'professor',
#  'Universidade',
#  'S\xc3\xa3o',
#  'Paulo',
#  '(USP)',
#  'autor',
#  'livros',
#  'sobre',
#  'hist\xc3\xb3ria',
#  'ditadura',
#  'militar',
#  'falar',
#  '\xe2\x80\x9cregime',
#  'democr\xc3\xa1tico',
#  'for\xc3\xa7a\xe2\x80\x9d',
#  'uma',
#  'contradi\xc3\xa7\xc3\xa3o',
#  '\xe2\x80\x9cEsta',
#  'mais',
#  'para',
#  'negacionismo',
#  'hist\xc3\xb3rico',
#  'que',
#  'revisionismo\xe2\x80\x9d',
#  'afirma',
#  'Napolitano',
#  'explica',
#  'que',
#  'conceito',
#  'negacionismo',
#  'tipo',
#  'afirma\xc3\xa7\xc3\xa3o',
#  'hist\xc3\xb3rica',
#  'que',
#  'n\xc3\xa3o',
#  'tem',
#  'base',
#  'documental',
#  'que',
#  'distorce',
#  'processo',
#  'factual',
#  'que',
#  'simplesmente',
#  'trabalha',
#  'com',
#  'documentos',
#  'falsos',
#  'com',
#  'objetivo',
#  'negar',
#  'processos',
#  'que',
#  's\xc3\xa3o',
#  'consensuais',
#  '\xe2\x80\x9cA',
#  'diferen\xc3\xa7a',
#  'sutil',
#  'mas',
#  'revisionismo',
#  'est\xc3\xa1',
#  'dentro',
#  'debate',
#  'historiogr\xc3\xa1fico',
#  'ancora',
#  'm\xc3\xa9todos',
#  'aceitos',
#  'cria',
#  'novos',
#  'objetos',
#  'pesquisa',
#  'novos',
#  'problemas',
#  'novas',
#  'quest\xc3\xb5es',
#  'fazendo',
#  'com',
#  'que',
#  'pr\xc3\xb3prio',
#  'historiador',
#  'questione',
#  'suas',
#  'cren\xc3\xa7as',
#  'que',
#  'saud\xc3\xa1vel\xe2\x80\x9d',
#  'conta',
#  '\xe2\x80\x9cJ\xc3\xa1',
#  'negacionismo',
#  'tem',
#  'ponto',
#  'partida',
#  'ideol\xc3\xb3gico',
#  'com',
#  'objetivo',
#  'ocultar',
#  'passado',
#  '\xe2\x80\x9dPesquisadores',
#  'que',
#  'estudam',
#  't\xc3\xaam',
#  'debru\xc3\xa7ado',
#  'sobre',
#  'quest\xc3\xa3o',
#  '\xe2\x80\x9c',
#  'apoiada',
#  'inclusive',
#  'por',
#  'alguns',
#  'historiadores',
#  'Mas',
#  'geral',
#  'comunidade',
#  'historiogr\xc3\xa1fica',
#  'n\xc3\xa3o',
#  'aceita',
#  'porque',
#  'ponto',
#  'partida',
#  'ocultar',
#  'que',
#  'aconteceu\xe2\x80\x9d',
#  'explica',
#  'Napolitano',
#  'professor',
#  'afirma',
#  'que',
#  'discuss\xc3\xb5es',
#  'historiogr\xc3\xa1ficas',
#  'mais',
#  'recentes',
#  'j\xc3\xa1',
#  'revisaram',
#  'muitos',
#  'aspectos',
#  'mem\xc3\xb3ria',
#  'sobre',
#  'ditadura',
#  'militar',
#  'Brasil',
#  'seu',
#  'artigo',
#  'Napolitano',
#  'afirma',
#  'que',
#  '\xe2\x80\x9cexiste',
#  'uma',
#  'mem\xc3\xb3ria',
#  'hegem\xc3\xb4nica',
#  'cr\xc3\xadtica',
#  'regime',
#  'militar\xe2\x80\x9d',
#  'constru\xc3\xadda',
#  'concord\xc3\xa2ncia',
#  'entre',
#  'setores',
#  'liberais',
#  '(que',
#  'at\xc3\xa9',
#  'apoiaram',
#  'golpe',
#  'inicialmente)',
#  'movimentos',
#  'das',
#  'esquerdas',
#  'mas',
#  'cuja',
#  'narrativa',
#  'j\xc3\xa1',
#  'passou',
#  'por',
#  'corre\xc3\xa7\xc3\xb5es',
#  'Por',
#  'exemplo',
#  '\xc3\xaanfase',
#  'vis\xc3\xa3o',
#  '\xe2\x80\x9csociedade',
#  'v\xc3\xadtima\xe2\x80\x9d',
#  'regime',
#  'golpe',
#  'como',
#  'obra',
#  'exclusiva',
#  'dos',
#  'militares',
#  '\xe2\x80\x9cNovas',
#  'abordagens',
#  'vem',
#  'problematizando',
#  'quest\xc3\xa3o',
#  'golpe',
#  'como',
#  'aus\xc3\xaancia',
#  'apoio',
#  'popular',
#  'Pois',
#  'h\xc3\xa1',
#  'evid\xc3\xaancia',
#  'apoio',
#  'passeatas',
#  'feitas',
#  'pela',
#  'classe',
#  'm\xc3\xa9dia',
#  'Por',
#  'mais',
#  'que',
#  'seja',
#  'inc\xc3\xb4modo',
#  'para',
#  'mem\xc3\xb3ria',
#  'esquerda',
#  'dizer',
#  'que',
#  'teve',
#  'apoio',
#  'Mas',
#  'foi',
#  'apoio',
#  'classe',
#  'm\xc3\xa9dia',
#  'n\xc3\xa3o',
#  'grupos',
#  'populares\xe2\x80\x9d',
#  'conta',
#  'Outra',
#  'revis\xc3\xa3o',
#  'sobre',
#  'percep\xc3\xa7\xc3\xa3o',
#  'comum',
#  'passado',
#  'que',
#  'guerrilha',
#  'armada',
#  'per\xc3\xadodo',
#  'militar',
#  'foi',
#  'rea\xc3\xa7\xc3\xa3o',
#  'ato',
#  'institucional',
#  'que',
#  'embruteceu',
#  'regime',
#  '\xe2\x80\x9cN\xc3\xa3o',
#  'foi',
#  'guerrilha',
#  'foi',
#  'projeto',
#  'anterior',
#  'como',
#  'rea\xc3\xa7\xc3\xa3o',
#  'golpe\xe2\x80\x9d',
#  'afirma',
#  'Napolitano',
#  'acordo',
#  'com',
#  'ele',
#  'medida',
#  'que',
#  'novas',
#  'fontes',
#  'documentos',
#  'v\xc3\xa3o',
#  'aparecendo',
#  'historiadores',
#  'podem',
#  'confrontar',
#  'mem\xc3\xb3ria',
#  'seja',
#  'direita',
#  'seja',
#  'esquerda',
#  '\xe2\x80\x9cEsse',
#  'trabalho',
#  'historiador',
#  'Nosso',
#  'compromisso',
#  'com',
#  'amplia\xc3\xa7\xc3\xa3o',
#  'conhecimento',
#  'n\xc3\xa3o',
#  'com',
#  'nega\xc3\xa7\xc3\xa3o',
#  'conhecimento',
#  '\xe2\x80\x9dApesar',
#  'afirmar',
#  'que',
#  'revisionismo',
#  'saud\xc3\xa1vel',
#  'Napolitano',
#  'afirma',
#  'que',
#  'h\xc3\xa1',
#  'limites',
#  'uma',
#  'vez',
#  'que',
#  'n\xc3\xa3o',
#  'pode',
#  'negar',
#  'aspectos',
#  'fundamentais',
#  'fato',
#  'hist\xc3\xb3rico',
#  'como',
#  'fato',
#  'que',
#  'ditadura',
#  'militar',
#  'Brasil',
#  'matou',
#  'centenas',
#  'pessoas',
#  'torturou',
#  'outras',
#  'milhares',
#  'colocando',
#  'xeque',
#  'direitos',
#  'civis',
#  'Brasil',
#  '\xe2\x80\x9cHist\xc3\xb3ria',
#  'mem\xc3\xb3ria',
#  's\xc3\xa3o',
#  'coisas',
#  'paralelas',
#  'por',
#  'isso',
#  'grupo',
#  'n\xc3\xa3o',
#  'pode',
#  'tentar',
#  'impor',
#  'sua',
#  'vis\xc3\xa3o',
#  'dos',
#  'fatos',
#  'debate',
#  'historiogr\xc3\xa1fico',
#  '"Napolitano',
#  'afirma',
#  'que',
#  'processos',
#  'revisionismo',
#  's\xc3\xa3o',
#  'frequentemente',
#  'turbulentos',
#  'muitas',
#  'vezes',
#  'fruto',
#  'luta',
#  'social',
#  'como',
#  'caso',
#  'hist\xc3\xb3ria',
#  'ind\xc3\xadgena',
#  'afrodescentes',
#  'historiografia',
#  'assumiu',
#  'ponto',
#  'vista',
#  'das',
#  'v\xc3\xadtimas',
#  'problematizou',
#  'narrativas',
#  'que',
#  'vinham',
#  'passado',
#  'professora',
#  'departamento',
#  'Hist\xc3\xb3ria',
#  'USP',
#  'que',
#  'estuda',
#  ...]

# %%
print(collections.Counter(text))
# Out:
# Counter({'que': 6493, 'para': 2212, 'uma': 2100, 'com': 2085, 'n\xc3\xa3o': 1721, 'por': 1229, 'como': 1211, 'mais': 1168, 'dos': 1057, 'sua': 761, 'das': 705, 'foi': 688, 'seu': 654, 'mas': 646, 'anos': 565, 'ser': 496, 'pelo': 462, 'pela': 459, 'tamb\xc3\xa9m': 445, 'nos': 429, 'sobre': 416, 'muito': 382, 'entre': 379, 's\xc3\xa3o': 370, 'est\xc3\xa1': 365, 'Bolsonaro': 358, 'presidente': 358, 'j\xc3\xa1': 352, 'isso': 350, 'ele': 331, 'quando': 326, 'tem': 323, 'era': 321, 'seus': 318, 'Brasil': 307, 'h\xc3\xa1': 305, 'Mas': 299, 'ainda': 287, 'nas': 281, 'depois': 280, 'pa\xc3\xads': 279, 'at\xc3\xa9': 278, '\xe2\x80\x93': 269, 'aos': 268, 'Governo': 265, 'sem': 255, 'ter': 252, 'suas': 231, 'pessoas': 229, 'N\xc3\xa3o': 226, 'contra': 226, 'dois': 219, 'porque': 219, 'foram': 208, 'mesmo': 207, 'ano': 206, 'onde': 205, 'diz': 204, 'vez': 200, 'pode': 198, 's\xc3\xb3': 198, 'parte': 190, 'tempo': 188, 'est\xc3\xa3o': 188, 'todos': 187, 'fazer': 184, 'essa': 182, 'menos': 178, 'mulheres': 177, 'segundo': 177, 'dia': 175, 'esse': 172, 'mundo': 171, 'ela': 171, '\xc3\xa0s': 169, 'vida': 168, 'disse': 166, 'tr\xc3\xaas': 163, 'outros': 163, 'tinha': 162, 'antes': 160, 'nem': 160, 'milh\xc3\xb5es': 160, 'maior': 158, 'caso': 155, 'apenas': 155, 'durante': 154, 'pol\xc3\xadtica': 154, 'desde': 152, 'havia': 148, 'outro': 146, '000': 142, 'primeiro': 141, 'trabalho': 141, 'primeira': 137, 'pelos': 136, 'dias': 136, 'cada': 135, 'forma': 132, 'hist\xc3\xb3ria': 131, 'ditadura': 131, 'qual': 131, 'estava': 131, 'agora': 129, 'poder': 129, 'grande': 129, 'eles': 127, 'hoje': 126, 'ap\xc3\xb3s': 125, 'quem': 124, 'seja': 124, 'todo': 124, 'assim': 122, 'reais': 121, 'passado': 121, 'pouco': 121, 'ministro': 120, 'tudo': 119, 't\xc3\xaam': 119, 'duas': 118, 'meses': 118, 'empresa': 118, 'grupo': 117, 'bem': 115, 'nesta': 115, 'sempre': 115, 'pa\xc3\xadses': 114, 'novo': 114, 'semana': 112, 'acordo': 112, 'qualquer': 112, 'S\xc3\xa3o': 111, 'momento': 109, 'conta': 109, 'militar': 108, 'ser\xc3\xa1': 107, 'alguns': 107, 'quase': 107, 'enquanto': 106, 'final': 105, 'pol\xc3\xadtico': 104, 'processo': 103, '2018': 103, 'Por': 102, 'militares': 102, 'casa': 101, 'Uma': 101, 'voc\xc3\xaa': 101, 'sido': 101, 'afirma': 100, 'al\xc3\xa9m': 100, 'algo': 100, 'Estado': 100, 'cidade': 99, 'disso': 98, 'Ele': 97, 'fam\xc3\xadlia': 96, 'exemplo': 96, 'vezes': 96, 'ent\xc3\xa3o': 96, 'outras': 94, 'Para': 93, 'nunca': 93, 'Com': 93, 'meio': 93, 'rela\xc3\xa7\xc3\xa3o': 92, 'sendo': 91, 'Como': 91, 'nova': 91, 'vai': 90, 'fez': 90, '\xc3\xa9poca': 89, 't\xc3\xa3o': 89, 'sociais': 89, 'C\xc3\xa2mara': 88, 'fato': 88, 'outra': 88, 'melhor': 88, 'Paulo': 88, 'Rio': 87, 'brasileiro': 87, 'situa\xc3\xa7\xc3\xa3o': 87, 'economia': 86, 'bilh\xc3\xb5es': 86, 'muitos': 86, 'podem': 85, 'teve': 85, 'p\xc3\xbablico': 85, 'seria': 85, 'deve': 85, 'faz': 84, 'afirmou': 82, 'lado': 82, 'poss\xc3\xadvel': 82, 'regime': 81, 'equipe': 81, 'importante': 80, 'lhe': 80, 'viol\xc3\xaancia': 80, 'empresas': 80, 'seis': 79, 'Estados': 79, 'explica': 79, 'quatro': 78, 'minha': 78, 'crian\xc3\xa7as': 78, 'fim': 77, 'ver': 77, 'sob': 77, 'sistema': 77, 'redes': 77, 'reforma': 76, 'mesma': 76, 'este': 76, 'preciso': 76, 'dados': 76, 'quanto': 75, 'Espanha': 75, 'gente': 75, 'quais': 74, 'dar': 74, 'pelas': 74, 'eram': 73, 'projeto': 73, 'embora': 73, 'Quando': 73, '\xc3\xbaltimo': 73, 'chegou': 72, 'apoio': 72, 'dentro': 72, 'Trump': 72, 'social': 72, '\xc3\xbaltimos': 71, 'todas': 71, '\xe2\x80\x9d': 71, 'cinco': 70, '2017': 70, 'ideia': 70, 'esquerda': 70, 'essas': 69, 'numa': 69, 'partido': 69, 'Nacional': 69, 'popula\xc3\xa7\xc3\xa3o': 69, 'per\xc3\xadodo': 68, 'governo': 68, 'partir': 68, 'nada': 68, 'pol\xc3\xadticas': 68, 'muitas': 68, 'Justi\xc3\xa7a': 68, '2016': 68, 'morte': 68, 'verdade': 68, 'tipo': 68, '\xe2\x80\x9cO': 68, 'mulher': 67, 'neste': 67, 'jogo': 67, 'elei\xc3\xa7\xc3\xb5es': 67, 'golpe': 67, '\xc3\xbaltima': 67, 'longo': 66, 'democracia': 66, 'num': 6 ...
